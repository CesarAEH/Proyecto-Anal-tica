# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df1 = pd.read_excel('datos_apartamentos_rent.xlsx')

# %% [markdown]
# **TAREA 2**

# %% [markdown]
# Estadisticas descriptivas sin gestionar los df1 faltantes y con outliers

# %%
mediabedrooms = np.mean(df1["bedrooms"])
print("media bedrooms=",mediabedrooms)
desviacionbedrooms = np.std(df1["bedrooms"])
print("desviacion bedrooms=",desviacionbedrooms)
minbedrooms = np.min(df1["bedrooms"])
print("min bedrooms=",minbedrooms)
# Out:
# media bedrooms= 1.7440208145701992
# desviacion bedrooms= 0.9423067885915578
# min bedrooms= 0.0

# %%
mediatime = np.mean(df1["time"])
print("media time=",mediatime)
desviaciontime = np.std(df1["time"])
print("desviacion time=",desviaciontime)
mintime = np.min(df1["time"])
print("min time=",mintime)
maxtime = np.max(df1["time"])
print("min time=",maxtime)
# Out:
# media time= 1574891175.3139
# desviacion time= 3762207.023184544
# min time= 1568743976
# min time= 1577362186

# %%
#El price_type puede ser Monthly o Weekly. Por esto algunos precios estan en temporalidad semanal
#Se multiplica por 4 los precios cuyo price-type es weekly para que pueda ser tomado como mensual
df1.loc[df1["price_type"] == "Weekly", "price"] *= 4

#Se calculan estadisticas del precio en temporalidad mensual
mediaprice = np.mean(df1["price"])
print("media price=",mediaprice)
desviacionprice = np.std(df1["price"])
print("desviacion price=",desviacionprice)
minprice = np.min(df1["price"])
print("min price=",minprice)
maxprice = np.max(df1["price"])
print("min price=",maxprice)
# Out:
# media price= 1486.7455
# desviacion price= 1077.502919963445
# min price= 200
# min price= 52500

# %%
df1.describe()
# Out:
#                  id    bathrooms     bedrooms         price   square_feet  \
# count  1.000000e+04  9966.000000  9993.000000  10000.000000  10000.000000
# mean   5.623396e+09     1.380544     1.744021   1486.745500    945.810500
# std    7.021025e+07     0.615410     0.942354   1077.556799    655.755736
# min    5.508654e+09     1.000000     0.000000    200.000000    101.000000
# 25%    5.509248e+09     1.000000     1.000000    949.000000    649.000000
# 50%    5.668610e+09     1.000000     2.000000   1270.000000    802.000000
# 75%    5.668626e+09     2.000000     2.000000   1695.000000   1100.000000
# max    5.668663e+09     8.500000     9.000000  52500.000000  40000.000000
#
#           latitude    longitude          time
# count  9990.000000  9990.000000  1.000000e+04
# mean     37.695162   -94.652247  1.574891e+09
# std       5.495851    15.759805  3.762395e+06
# min      21.315500  -158.022100  1.568744e+09
# 25%      33.679850  -101.301700  1.568781e+09
# ...

# %% [markdown]
# Estadisticas descriptivas Variables no numericas sin gestionar datos faltantes y con outliers

# %%
#valores unicos columna has_photo
unicoshas_photo = df1['has_photo'].unique()
print ("unicos has_photo=", unicoshas_photo)

#veces que aparecen los únicos de columna has_photo
df1.groupby(['has_photo']).count()

contarhas_photo = df1['has_photo'].value_counts()
print("contar has_photo=", contarhas_photo)
# Out:
# unicos has_photo= ['Thumbnail' 'Yes' 'No']
# contar has_photo= has_photo
# Thumbnail    8907
# Yes           909
# No            184
# Name: count, dtype: int64

# %%
#valores unicos columna cityname
unicoscityname = df1['cityname'].unique()
print ("unicos cityname=", unicoscityname)

#veces que aparecen los únicos de columna cityname
df1.groupby(['cityname']).count()

#se extrajeron las 5 ciudades que mas se repiten debido a la gran cantidad de estados
contarcityname = df1['cityname'].value_counts().head()
print("contar cityname=", contarcityname)

#aca se muestran todos las ciudades en caso de que se necesite ver las veces que se repite cada uno
contarcityname1 = df1['cityname'].value_counts()
print("contar cityname todos=", contarcityname1)
# Out:
# unicos cityname= ['Washington' 'Evansville' 'Arlington' ... 'Saint Leonard' 'Chaska'
#  'Bella Vista']
# contar cityname= cityname
# Austin         523
# Dallas         216
# Houston        186
# San Antonio    182
# Los Angeles    165
# Name: count, dtype: int64
# contar cityname todos= cityname
# Austin           523
# Dallas           216
# Houston          186
# San Antonio      182
# Los Angeles      165
#                 ...
# Bradley            1
# Paris              1
# Mission Viejo      1
# Menlo Park         1
# Rosemount          1
# Name: count, Length: 1574, dtype: int64

# %%
#valores unicos columna state
unicosstate = df1['state'].unique()
print ("unicos state=", unicosstate)

#veces que aparecen los únicos de columna state
df1.groupby(['state']).count()

#se extrajeron los 5 estados que mas se repiten debido a la gran cantidad de estados
contarstate = df1['state'].value_counts().head()
print("contar state=", contarstate)

#aca se muestran todos los estados en caso de que se necesite ver las veces que se repite cada uno
contarstate1 = df1['state'].value_counts()
print("contar state todos=", contarstate1)
# Out:
# unicos state= ['DC' 'IN' 'VA' 'WA' 'NY' 'CA' 'AZ' 'NC' 'TX' 'GA' 'FL' nan 'AL' 'MD' 'CO'
#  'NM' 'IL' 'TN' 'AK' 'MA' 'NJ' 'OR' 'DE' 'PA' 'IA' 'SC' 'MN' 'MI' 'KY'
#  'WI' 'OH' 'CT' 'RI' 'NV' 'UT' 'MO' 'OK' 'NH' 'NE' 'LA' 'ND' 'AR' 'KS'
#  'ID' 'HI' 'MT' 'VT' 'SD' 'WV' 'MS' 'ME' 'WY']
# contar state= state
# TX    1737
# CA     955
# WA     519
# NC     438
# MD     424
# Name: count, dtype: int64
# contar state todos= state
# TX    1737
# CA     955
# WA     519
# NC     438
# MD     424
# NJ     383
# GA     372
# FL     339
# OH     321
# CO     318
# WI     302
# IL     282
# MO     239
# IN     239
# MN     221
# VA     205
# OR     197
# PA     183
# IA     179
# OK     178
# MI     176
# MA     167
# AZ     126
# NV     121
# ND     113
# NE     105
# CT      98
# TN      92
# UT      84
# KS      83
# DC      80
# SC      77
# NY      71
# NH      70
# SD      66
# LA      66
# AR      56
# AL      56
# AK      44
# KY      40
# ID      21
# VT      16
# NM      14
# ...

# %%
#valores unicos columna pets_allowed
unicospets_allowed = df1['pets_allowed'].unique()
print ("unicos pets_allowed=", unicospets_allowed)

#veces que aparecen los únicos de columna pets_allowed
df1.groupby(['pets_allowed']).count()

contarpets_allowed = df1['pets_allowed'].value_counts()
print("contar pets_allowed=", contarpets_allowed)
# Out:
# unicos pets_allowed= [nan 'Cats,Dogs' 'Cats' 'Dogs']
# contar pets_allowed= pets_allowed
# Cats,Dogs    5228
# Cats          485
# Dogs          124
# Name: count, dtype: int64

# %%
#valores unicos columna source
unicossource = df1['source'].unique()
print ("unicos source=", unicossource)

#veces que aparecen los únicos de columna source
df1.groupby(['source']).count()

contarsource = df1['source'].value_counts()
print("contar source=", contarsource)
# Out:
# unicos source= ['RentLingo' 'Listanza' 'ListedBuy' 'RentDigs.com' 'GoSection8'
#  'RealRentals' 'RENTOCULAR' 'rentbits' 'Home Rentals' 'Real Estate Agent'
#  'RENTCafé' 'tenantcloud']
# contar source= source
# RentLingo            6912
# RentDigs.com         2764
# ListedBuy             179
# RealRentals            69
# GoSection8             31
# Listanza               23
# RENTOCULAR             16
# rentbits                2
# Home Rentals            1
# Real Estate Agent       1
# RENTCafé                1
# tenantcloud             1
# Name: count, dtype: int64

# %% [markdown]
# *Diagramas con outliers*

# %% [markdown]
# Histograma precios

# %%
#histograma price con outliers
plt.hist(df1['price'], bins=10, range=[200,10000])
plt.title('Distribucion de los precios con un rango entre 200 y 10000')
plt.show()

# %% [markdown]
# Histograma del tiempo tras la publicacion

# %%
#histograma time sin outliers
plt.hist(df1['time'])
plt.title('Distribucion del tiempo tras la publicación')
plt.show()

# %%
#diagrama de dispercion price y time con outliers
# Crear el diagrama de dispersión square_feet y price con outliers  
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df1, x="time", y="price", alpha=0.5)

plt.title("Diagrama de Dispersión: tiempo vs precio con outliers")
plt.xlabel("Tiempo")
plt.ylabel("Precio")
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %%
# Boxplot pets allowed y price con outliers
sns.boxplot(data=df1, x="pets_allowed", y="price", palette="Paired")

plt.title("Distribución del Precio por mascotas permitidas (Con Outliers)", fontsize=14)
plt.xlabel("Mascotas permitidas")
plt.ylabel("Precio")
plt.xticks(rotation=45)  # Rotar etiquetas si hay muchas categorías
plt.grid(True, linestyle="--", alpha=0.5)

plt.show()
# Out:
# C:\Users\arced\AppData\Local\Temp\ipykernel_40372\2293702755.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df1, x="pets_allowed", y="price", palette="Paired")

# %% [markdown]
# Boxplot por categoria source y price

# %%
# Box plot price y source con outliers
sns.boxplot(data=df1, x="source", y="price", palette="Paired")


plt.title("Distribución del Precio por source (Con Outliers)", fontsize=14)
plt.xlabel("Source")
plt.ylabel("Precio")
plt.xticks(rotation=45)  # Rotar etiquetas si hay muchas categorías
plt.grid(True, linestyle="--", alpha=0.5)

# Mostrar el gráfico
plt.show()
# Out:
# C:\Users\arced\AppData\Local\Temp\ipykernel_40372\3700806492.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df1, x="source", y="price", palette="Paired")

# %% [markdown]
# Diagrama de dispercion entre square_feet y price

# %%
# Crear el diagrama de dispersión square_feet y price con outliers  
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df1, x="square_feet", y="price", alpha=0.5)

plt.title("Diagrama de Dispersión: pies cuadrados vs precio")
plt.xlabel("Pies cuadrados")
plt.ylabel("Precio")
plt.grid(True)


plt.show()

# %%
#boxplot bedrooms y price con outliers

plt.figure(figsize=(10, 5))

# boxplot sin outliers
sns.boxplot(data=df1, x="bedrooms", y="price", palette="Paired")

plt.title("Distribución del Precio por numero de habitaciones (Con Outliers)", fontsize=14)
plt.xlabel("Habitaciones")
plt.ylabel("Precio")
plt.xticks(rotation=45)  # Rotar etiquetas si hay muchas categorías
plt.grid(True, linestyle="--", alpha=0.5)

# Mostrar el gráfico
plt.show()
# Out:
# C:\Users\arced\AppData\Local\Temp\ipykernel_40372\2754781675.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df1, x="bedrooms", y="price", palette="Paired")

# %%
#Boxplot bathrooms y price con outliers
# Crear el boxplot sin valores atípicos
plt.figure(figsize=(10, 5))
sns.boxplot(data=df1, x="bathrooms", y="price", palette="Paired")

plt.title("Distribución del Precio por numero de baños (Con Outliers)", fontsize=14)
plt.xlabel("Baños")
plt.ylabel("Precio")
plt.xticks(rotation=45)  # Rotar etiquetas si hay muchas categorías
plt.grid(True, linestyle="--", alpha=0.5)

plt.show()
# Out:
# C:\Users\arced\AppData\Local\Temp\ipykernel_40372\2978902175.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df1, x="bathrooms", y="price", palette="Paired")

# %%
# %matplotlib inline

# %%
sns.pairplot(df1,)

# %%
corr = df1.corr(numeric_only=True)  # Calculate correlation for numeric columns only
sns.heatmap(corr, cmap="Blues", annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df1, x_vars=['bathrooms','bedrooms','square_feet'], y_vars='price', height=7, aspect=0.7, kind='reg')
sns.pairplot(df1, x_vars=['bathrooms'], y_vars='bedrooms', height=7, aspect=0.7, kind='reg')
sns.pairplot(df1, x_vars=['bathrooms'], y_vars='square_feet', height=7, aspect=0.7, kind='reg')
sns.pairplot(df1, x_vars=['bedrooms'], y_vars='square_feet', height=7, aspect=0.7, kind='reg')

# %% [markdown]
# *SIN OUTLIERS*

# %%
#se seleccionan solo las columnas price, square feet, time
colfiltrar = [ "square_feet","price", "time"]
columnasfiltradas = df1[colfiltrar]

#QI,cuartil3 y rango intercuartil
cuartil1 = columnasfiltradas.quantile(0.25)
cuartil3 = columnasfiltradas.quantile(0.75)
IQR = cuartil3 - cuartil1

#limites
limsuperior = cuartil3 + 1.5 * IQR
liminferior = cuartil1 - 1.5 * IQR

# se seleccionan los valores segun los limites
df = df1[~((columnasfiltradas < liminferior) | (columnasfiltradas > limsuperior)).any(axis=1)]

# %% [markdown]
# SIN OUTLIERS GRAFICAS

# %%
#histograma price sin outliers
plt.hist(df['price'], bins=20)
plt.title('Distribucion de los precios sin outliers')
plt.show()

# %%
#histograma time sin outliers
plt.hist(df['time'])
plt.title('Distribucion del tiempo tras la publicación sin outliers')
plt.show()

# %%
#diagrama de dispercion price y time sin outliers
# Crear el diagrama de dispersión square_feet y price sin outliers  
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="time", y="price", alpha=0.5)

plt.title("Diagrama de Dispersión: tiempo vs precio sin outliers")
plt.xlabel("Tiempo")
plt.ylabel("Precio")
plt.grid(True)

plt.show()

# %%
# Boxplot pets allowed y price sin outliers
sns.boxplot(data=df, x="pets_allowed", y="price", palette="Paired")

plt.title("Distribución del Precio por mascotas permitidas (sin outliers)", fontsize=14)
plt.xlabel("Mascotas permitidas")
plt.ylabel("Precio")
plt.xticks(rotation=45) 
plt.grid(True, linestyle="--", alpha=0.5)

plt.show()
# Out:
# C:\Users\arced\AppData\Local\Temp\ipykernel_40372\2342678721.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="pets_allowed", y="price", palette="Paired")

# %%
# Box plot price y source sin outliers
sns.boxplot(data=df, x="source", y="price", palette="Paired")

plt.title("Distribución del Precio por source (Sin Outliers)", fontsize=14)
plt.xlabel("Source")
plt.ylabel("Precio")
plt.xticks(rotation=45)  # Rotar etiquetas si hay muchas categorías
plt.grid(True, linestyle="--", alpha=0.5)


plt.show()
# Out:
# C:\Users\arced\AppData\Local\Temp\ipykernel_40372\5994660.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="source", y="price", palette="Paired")

# %%
# Crear el diagrama de dispersión square_feet y price sin outliers  
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="square_feet", y="price", alpha=0.5)

plt.title("Diagrama de Dispersión: pies cuadrados vs precio")
plt.xlabel("Pies cuadrados")
plt.ylabel("Precio")
plt.grid(True)

plt.show()

# %%
#boxplot bedrooms y price sin outliers

plt.figure(figsize=(10, 5))

#boxplot sin outliers
sns.boxplot(data=df, x="bedrooms", y="price", palette="Paired")

plt.title("Distribución del Precio por numero de habitaciones (Sin Outliers)", fontsize=14)
plt.xlabel("Habitaciones")
plt.ylabel("Precio")
plt.xticks(rotation=45)  # Rotar etiquetas si hay muchas categorías
plt.grid(True, linestyle="--", alpha=0.5)

plt.show()
# Out:
# C:\Users\arced\AppData\Local\Temp\ipykernel_40372\3491778708.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="bedrooms", y="price", palette="Paired")

# %%
#Boxplot bathrooms y price sin outliers
# Crear el boxplot sin valores atípicos
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x="bathrooms", y="price", palette="Paired")

plt.title("Distribución del Precio por numero de baños (Sin Outliers)", fontsize=14)
plt.xlabel("Baños")
plt.ylabel("Precio")
plt.xticks(rotation=45)  # Rotar etiquetas si hay muchas categorías
plt.grid(True, linestyle="--", alpha=0.5)


plt.show()
# Out:
# C:\Users\arced\AppData\Local\Temp\ipykernel_40372\1053112762.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="bathrooms", y="price", palette="Paired")

# %% [markdown]
# Estadisticas descriptivas SIN OUTLIERS

# %%
df.describe()
# Out:
#                  id    bathrooms     bedrooms        price  square_feet  \
# count  8.949000e+03  8920.000000  8943.000000  8949.000000  8949.000000
# mean   5.621156e+09     1.277578     1.596444  1283.166052   831.574031
# std    7.135191e+07     0.472914     0.773973   486.977990   303.850180
# min    5.508654e+09     1.000000     0.000000   200.000000   101.000000
# 25%    5.509230e+09     1.000000     1.000000   915.000000   630.000000
# 50%    5.668609e+09     1.000000     1.000000  1200.000000   777.000000
# 75%    5.668625e+09     1.500000     2.000000  1554.000000  1000.000000
# max    5.668643e+09     4.000000     6.000000  2810.000000  1776.000000
#
#           latitude    longitude          time
# count  8939.000000  8939.000000  8.949000e+03
# mean     37.745092   -93.972328  1.574772e+09
# std       5.566135    15.168417  3.823938e+06
# min      21.315500  -158.022100  1.568744e+09
# 25%      33.529250   -98.525300  1.568780e+09
# ...

# %%
#valores unicos columna has_photo
unicoshas_photo = df['has_photo'].unique()
print ("unicos has_photo=", unicoshas_photo)

#veces que aparecen los únicos de columna has_photo
df.groupby(['has_photo']).count()

contarhas_photo = df['has_photo'].value_counts()
print("contar has_photo=", contarhas_photo)
# Out:
# unicos has_photo= ['Thumbnail' 'Yes' 'No']
# contar has_photo= has_photo
# Thumbnail    7924
# Yes           859
# No            166
# Name: count, dtype: int64

# %%
#valores unicos columna cityname
unicoscityname = df['cityname'].unique()
print ("unicos cityname=", unicoscityname)

#veces que aparecen los únicos de columna cityname
df.groupby(['cityname']).count()

#se extrajeron las 5 ciudades que mas se repiten debido a la gran cantidad de estados
contarcityname = df['cityname'].value_counts().head()
print("contar cityname=", contarcityname)

#aca se muestran todos las ciudades en caso de que se necesite ver las veces que se repite cada uno
contarcityname1 = df['cityname'].value_counts()
print("contar cityname todos=", contarcityname1)
# Out:
# unicos cityname= ['Washington' 'Evansville' 'Arlington' ... 'American Canyon' 'Belgrade'
#  'Locust']
# contar cityname= cityname
# Austin         521
# Dallas         208
# Houston        181
# San Antonio    177
# Chicago        131
# Name: count, dtype: int64
# contar cityname todos= cityname
# Austin         521
# Dallas         208
# Houston        181
# San Antonio    177
# Chicago        131
#               ...
# Channelview      1
# Willis           1
# Berlin           1
# Grand Haven      1
# Acworth          1
# Name: count, Length: 1441, dtype: int64

# %%
#valores unicos columna state
unicosstate = df['state'].unique()
print ("unicos state=", unicosstate)

#veces que aparecen los únicos de columna state
df.groupby(['state']).count()

#se extrajeron los 5 estados que mas se repiten debido a la gran cantidad de estados
contarstate = df['state'].value_counts().head()
print("contar state=", contarstate)

#aca se muestran todos los estados en caso de que se necesite ver las veces que se repite cada uno
contarstate1 = df['state'].value_counts()
print("contar state todos=", contarstate1)
# Out:
# unicos state= ['DC' 'IN' 'VA' 'WA' 'NY' 'CA' 'AZ' 'NC' 'TX' 'GA' 'FL' nan 'AL' 'MD' 'CO'
#  'NM' 'IL' 'TN' 'AK' 'MA' 'NJ' 'OR' 'DE' 'PA' 'IA' 'SC' 'MN' 'MI' 'KY'
#  'WI' 'OH' 'CT' 'RI' 'NV' 'UT' 'MO' 'OK' 'NH' 'NE' 'LA' 'ND' 'AR' 'KS'
#  'ID' 'HI' 'MT' 'VT' 'SD' 'WV' 'MS' 'ME' 'WY']
# contar state= state
# TX    1674
# CA     620
# WA     475
# MD     412
# NC     396
# Name: count, dtype: int64
# contar state todos= state
# TX    1674
# CA     620
# WA     475
# MD     412
# NC     396
# GA     336
# NJ     329
# OH     300
# CO     298
# WI     294
# FL     291
# IL     258
# MO     230
# IN     213
# MN     212
# VA     185
# PA     175
# IA     174
# OR     168
# OK     162
# MI     155
# MA     130
# AZ     115
# ND     107
# NV     105
# NE     101
# CT      97
# TN      84
# KS      75
# UT      71
# NH      69
# DC      66
# NY      62
# SD      61
# LA      60
# SC      55
# AR      51
# AL      45
# AK      43
# KY      39
# ID      18
# VT      15
# NM      14
# ...

# %%
#valores unicos columna pets_allowed
unicospets_allowed = df['pets_allowed'].unique()
print ("unicos pets_allowed=", unicospets_allowed)

#veces que aparecen los únicos de columna pets_allowed
df.groupby(['pets_allowed']).count()

contarpets_allowed = df['pets_allowed'].value_counts()
print("contar pets_allowed=", contarpets_allowed)
# Out:
# unicos pets_allowed= [nan 'Cats,Dogs' 'Cats' 'Dogs']
# contar pets_allowed= pets_allowed
# Cats,Dogs    4685
# Cats          455
# Dogs           71
# Name: count, dtype: int64

# %%
#valores unicos columna source
unicossource = df['source'].unique()
print ("unicos source=", unicossource)

#veces que aparecen los únicos de columna source
df.groupby(['source']).count()

contarsource = df['source'].value_counts()
print("contar source=", contarsource)
# Out:
# unicos source= ['RentLingo' 'Listanza' 'RentDigs.com' 'ListedBuy' 'GoSection8'
#  'RealRentals' 'RENTOCULAR' 'rentbits' 'Home Rentals' 'Real Estate Agent'
#  'RENTCafé' 'tenantcloud']
# contar source= source
# RentLingo            6041
# RentDigs.com         2606
# ListedBuy             169
# RealRentals            66
# GoSection8             30
# Listanza               18
# RENTOCULAR             13
# rentbits                2
# Home Rentals            1
# Real Estate Agent       1
# RENTCafé                1
# tenantcloud             1
# Name: count, dtype: int64

# %%
# %matplotlib inline

# %%
sns.pairplot(df,)

# %%
#correlacion para variables numericas
corr = df.corr(numeric_only=True)  
sns.heatmap(corr, cmap="Blues", annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df, x_vars=['bathrooms','bedrooms','square_feet'], y_vars='price', height=7, aspect=0.7, kind='reg')
sns.pairplot(df, x_vars=['bathrooms'], y_vars='bedrooms', height=7, aspect=0.7, kind='reg')
sns.pairplot(df, x_vars=['bathrooms'], y_vars='square_feet', height=7, aspect=0.7, kind='reg')
sns.pairplot(df, x_vars=['bedrooms'], y_vars='square_feet', height=7, aspect=0.7, kind='reg')
